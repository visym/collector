# %% [markdown]
# # Dropbox Integration

# %% [markdown]
# * You may link your dropbox to save your own copy of videos.
# * This integration is write-only a single App directory (we can't see your Dropbox!)
# * Integration is performed following the link in your profile in-app

# %%
import pycollector.video
v = pycollector.video.Video(mp4file='/Users/jebyrne/Dropbox (Personal)/Apps/Visym Collector/DC65FA28-1E6D-44D0-AED3-AA541EA6696E.mp4',
                            jsonfile='/Users/jebyrne/Dropbox (Personal)/Apps/Visym Collector/DC65FA28-1E6D-44D0-AED3-AA541EA6696E_20210514_170931.json')
print(v)
# Out:
# <pycollector.video: uploaded=2021-05-14 13:09, activities={'person_signing_thank_you'}, scene=<vipy.video.scene: filename="/Users/jebyrne/Dropbox (Personal)/Apps/Visym Collector/DC65FA28-1E6D-44D0-AED3-AA541EA6696E.mp4", fps=30.0, category="Thank You", tracks=1, activities=1>>

# %%
v.annotate().frame(30).show()
# Out:
# [vipy.video.annotate]: Annotating video ...
# <vipy.image: height=910, width=512, color=rgb>
