# %% [markdown]
# # Downloading Videos

# %% [markdown]
# * Download and install the app, and collect one of the "Practice" videos.
# * You may retrieve your video using the registered email address and password created in-app
# * All annotated videos are stored using [vipy](https://github.com/visym/vipy) format

# %%
import pycollector.video
v = pycollector.video.last(program='Practice')
print(v)
# Out:
# <pycollector.video: uploaded=2021-04-19 08:29, activities=set(), scene=<vipy.video.scene: filename="/Users/jebyrne/.vipy/83322cd2-7c59-406c-86a6-23e698619e425456175993824533149.mp4", url="s3://visym-data-lake140008-visymcprod.s3.amazonaws.com/uploads/Programs/Practice/Getting Started/83322cd2-7c59-406c-86a6-23e698619e425456175993824533149.mp4", fps=14.9, category="What is Visym Collector?", tracks=1>>

# %%
# Visualize the first frame of this video.  
# This is obviously a junk testing video, since it is not a person
v[0].show()
# Out:
# <vipy.image.scene: height=910, width=512, color=rgb, category="What is Visym Collector?", objects=1>
